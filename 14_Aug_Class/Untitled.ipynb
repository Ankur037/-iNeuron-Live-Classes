# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha = 0.4)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha = 0.1)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha = 0.9)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha = 0.4, stacked = False)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 1000)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10, cmap= "viridis")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#3D plot

from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1.6 , 30)

# %%
x
# Out:
# array([-1.6       , -0.95510204, -0.31020408,  0.33469388,  0.97959184,
#         1.6244898 ,  2.26938776,  2.91428571,  3.55918367,  4.20408163,
#         4.84897959,  5.49387755,  6.13877551,  6.78367347,  7.42857143,
#         8.07346939,  8.71836735,  9.36326531, 10.00816327, 10.65306122,
#        11.29795918, 11.94285714, 12.5877551 , 13.23265306, 13.87755102,
#        14.52244898, 15.16734694, 15.8122449 , 16.45714286, 17.10204082,
#        17.74693878, 18.39183673, 19.03673469, 19.68163265, 20.32653061,
#        20.97142857, 21.61632653, 22.26122449, 22.90612245, 23.55102041,
#        24.19591837, 24.84081633, 25.48571429, 26.13061224, 26.7755102 ,
#        27.42040816, 28.06530612, 28.71020408, 29.35510204, 30.        ])

# %%
y = np.linspace(-1.6 , 30)

# %%
y
# Out:
# array([-1.6       , -0.95510204, -0.31020408,  0.33469388,  0.97959184,
#         1.6244898 ,  2.26938776,  2.91428571,  3.55918367,  4.20408163,
#         4.84897959,  5.49387755,  6.13877551,  6.78367347,  7.42857143,
#         8.07346939,  8.71836735,  9.36326531, 10.00816327, 10.65306122,
#        11.29795918, 11.94285714, 12.5877551 , 13.23265306, 13.87755102,
#        14.52244898, 15.16734694, 15.8122449 , 16.45714286, 17.10204082,
#        17.74693878, 18.39183673, 19.03673469, 19.68163265, 20.32653061,
#        20.97142857, 21.61632653, 22.26122449, 22.90612245, 23.55102041,
#        24.19591837, 24.84081633, 25.48571429, 26.13061224, 26.7755102 ,
#        27.42040816, 28.06530612, 28.71020408, 29.35510204, 30.        ])

# %%
def sin_fun(x,y):
    return np.sin(np.sqrt(x**2 + y**2))

# %%
z= x +y

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'], df['sepal_width'], df['petal_length'])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
#increase size of window

df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
#Bar Graph

df.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'barh', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind = 'hist', figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df ['sepal_length'].plot(kind = 'hist', figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize = (20,10), color = 'g', alpha = 0.9) # aplha= manage color density
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10), color = '#EDC126', alpha = 0.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# !pip install cufflinks

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot(x='sepal_length' ,y= 'sepal_width' , kind = 'scatter' )
# Out:
# <div>                            <div id="8d14f025-c764-455c-81a2-ee213cad3fa3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width', kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="3b269d2d-5111-4668-823a-76d2facbfa21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length' ,y= 'sepal_width' , z= 'petal_length' , size = 'sepal_length' , kind = 'bubble3d' )
# Out:
# <div>                            <div id="3a4bb395-6676-4e19-b4b7-bf792486f872" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width', z = 'petal_length', size = 'sepal_length', kind = 'bubble3d')
# Out:
# <div>                            <div id="b7d6ccd3-4674-4e98-b102-f8cc96fe510f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')

# %% [markdown]
# #

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x = 'total_bill', y = 'tip', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x = 'total_bill', y = 'tip', kind = 'scatter', mode ='markers')
# Out:
# <div>                            <div id="b14aac7d-9eb3-43c0-9026-4f08ef34233e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 [ 'smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'time', style = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'time', style = 'sex')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, hue = 'size', style = 'size')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, col = 'time')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x = 'sepal_length', y = 'sepal_width', data = df, col = 'species')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df1, col = 'day')

# %%
#Cat Plot

sns.catplot(x = 'day', y = 'total_bill', data = df1)

# %%
sns.pairplot(df1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="c612cfa5-dc24-4ade-980e-ff79fdbb033d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11756/3316429496.py in <module>
# ----> 1 df1.scatter_matrix()
#
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in _scatter_matrix(self, theme, bins, color, size, asFigure, **iplot_kwargs)
#    1278                         Keyword arguments to pass through to `iplot`
#    1279 	"""
# -> 1280         sm=tools.scatter_matrix(self,theme=theme,bins=bins,color=color,size=size)
#    1281         if asFigure:
#    1282                 return sm
#
# ~\anaconda3\lib\site-packages\cufflinks\tools.py in scatter_matrix(df, theme, bins, color, size)
#    1018                                 figs.append(fig)
#    1019                         else:
# -> 1020                                 figs.append(df.iplot(kind='scatter',mode='markers',x=j,y=i,asFigure=True,size=size,colors=[color]))
# ...

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x = df1.total_bill, y = df1.tip)

# %%
sns.jointplot(x = df1.total_bill, y = df1.tip, kind = 'hex')

# %%
sns.pairplot(df1)

# %%
#regression plot

sns.regplot(x = df1.total_bill, y = df1.tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#regression plot


sns.regplot(x = df1.total_bill, y = df1.tip)
sns.set(rc = {'figure.figsize': (20,10)})

# %%
import plotly.express as px
df = px.data.iris()
df["e"] = df["sepal_width"]/100
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", error_x="e", error_y="e")
fig.show()
# Out:
# <div>                            <div id="bf83eea5-cc68-4e74-bf44-3711ca26bcc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf83eea5-cc68-4e74-bf44-3711ca26bcc6")) {                    Plotly.newPlot(                        "bf83eea5-cc68-4e74-bf44-3711ca26bcc6",                        [{"error_x":{"array":[0.035,0.03,0.032,0.031,0.036000000000000004,0.039,0.034,0.034,0.028999999999999998,0.031,0.037000000000000005,0.034,0.03,0.03,0.04,0.044000000000000004,0.039,0.035,0.038,0.038,0.034,0.037000000000000005,0.036000000000000004,0.033,0.034,0.03,0.034,0.035,0.034,0.032,0.031,0.034,0.040999999999999995,0.042,0.031,0.032,0.035,0.031,0.03,0.034,0.035,0.023,0.032,0.035,0.038,0.03,0.038,0.032,0.037000000000000005,0.033]},"error_y":{"array":[0.035,0.03,
# ...

# %%
import plotly.express as px


fig = px.bar(df1, x = "sex", y = "total_bill", color= "smoker", barmode= "group")
fig.show()
# Out:
# <div>                            <div id="4aa3d90f-4c2d-40a9-b286-cd20e11aeb8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aa3d90f-4c2d-40a9-b286-cd20e11aeb8c")) {                    Plotly.newPlot(                        "4aa3d90f-4c2d-40a9-b286-cd20e11aeb8c",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %%
cufflinks - https://github.com/santosjorge/cufflinks
plotly - https://ploty.com/python/plotly-express/
seaborn - https://seaborn.pydata.org/index.html
matplotalib- https://matplotlib.org/stable/index.html

# %%
import plotly.express as px


fig1 = px.scatter(df1, x = "total_bill", y = "tip", color= "time")
fig1.show()
# Out:
# <div>                            <div id="575a8f06-2998-43a2-b8a4-d47e114f904c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("575a8f06-2998-43a2-b8a4-d47e114f904c")) {                    Plotly.newPlot(                        "575a8f06-2998-43a2-b8a4-d47e114f904c",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...
